# %%
#THis github is like a book for this topic, got to the link or clone it, you will find a lot more resources
# !git clone https://github.com/ine-rmotr-curriculum/RDP-Reading-Data-with-Python-and-Pandas.git
# Out:
# Cloning into 'RDP-Reading-Data-with-Python-and-Pandas'...
# remote: Enumerating objects: 366, done.
# remote: Total 366 (delta 0), reused 0 (delta 0), pack-reused 366
# Receiving objects: 100% (366/366), 882.28 KiB | 10.89 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
