# %%
#THis github can be useful and we can get dataset directly
# !git clone https://github.com/ine-rmotr-curriculum/freecodecamp-intro-to-pandas.git
# Out:
# Cloning into 'freecodecamp-intro-to-pandas'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 16 (delta 6), reused 16 (delta 6), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.read_csv?

# %%
df = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/btc-market-price.csv")

# %%
df
# Out:
#      2017-04-02 00:00:00  1099.169125
# 0    2017-04-03 00:00:00  1141.813000
# 1    2017-04-04 00:00:00  1141.600363
# 2    2017-04-05 00:00:00  1133.079314
# 3    2017-04-06 00:00:00  1196.307937
# 4    2017-04-07 00:00:00  1190.454250
# ..                   ...          ...
# 359  2018-03-28 00:00:00  7960.380000
# 360  2018-03-29 00:00:00  7172.280000
# 361  2018-03-30 00:00:00  6882.531667
# 362  2018-03-31 00:00:00  6935.480000
# 363  2018-04-01 00:00:00  6794.105000
#
# [364 rows x 2 columns]

# %%
df.head()
# Out:
#    2017-04-02 00:00:00  1099.169125
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
df.describe()
# Out:
#         1099.169125
# count    364.000000
# mean    6374.025903
# std     4526.677236
# min     1133.079314
# 25%     2588.210962
# 50%     4598.634367
# 75%     9208.168450
# max    19498.683333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2017-04-02 00:00:00  364 non-null    object
#  1   1099.169125          364 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
df = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/btc-market-price.csv", header=None)

# %%
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.columns = ["Timestamp", "Price"]

# %%
df.head()
# Out:
#              Timestamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.shape
# Out:
# (365, 2)

# %%
df.tail(3)
# Out:
#                Timestamp        Price
# 362  2018-03-30 00:00:00  6882.531667
# 363  2018-03-31 00:00:00  6935.480000
# 364  2018-04-01 00:00:00  6794.105000

# %%
df.iloc[-1]
# Out:
# Timestamp    2018-04-01 00:00:00
# Price                     6794.1
# Name: 364, dtype: object

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
pd.to_datetime(df["Timestamp"]).head()
# Out:
# 0   2017-04-02
# 1   2017-04-03
# 2   2017-04-04
# 3   2017-04-05
# 4   2017-04-06
# Name: Timestamp, dtype: datetime64[ns]

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-04-02  1099.169125
# 1 2017-04-03  1141.813000
# 2 2017-04-04  1141.600363
# 3 2017-04-05  1133.079314
# 4 2017-04-06  1196.307937

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %%
df.set_index(["Timestamp"], inplace=True)

# %%
df.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
df.loc["2017-04-04"]
# Out:
# Price    1141.600363
# Name: 2017-04-04 00:00:00, dtype: float64

# %% [markdown]
# ## **Putting everything together**
# And now, we've finally arrived to the final, desired version of the DataFrame parsed from our CSV file. The steps were:

# %%
df = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/btc-market-price.csv",header = None)
df.columns = ["Timestamp", "Price"]
df["Timestamp"] = pd.to_datetime(df["Timestamp"])
df.set_index("Timestamp", inplace=True)

# %%
df.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
#Shortcut
df = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/btc-market-price.csv",
                 header=None,
                 names=["Timestamp","Price"],
                 index_col=0,
                 parse_dates=True)

# %%
df.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
df.loc["2017-04-06"]
# Out:
# Price    1196.307937
# Name: 2017-04-06 00:00:00, dtype: float64

# %% [markdown]
# ## **Plotting basics**
# pandas integrates with Matplotlib and creating a plot is as simple as:

# %%
df.plot()

# %%
df.plot().set_ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.plot(df.index, df["Price"])

# %%
x = np.arange(-10, 11)

# %%
plt.plot(x, x**2)

# %%
plt.plot(x, -1 * (x**2))

# %%
plt.figure(figsize=(14,7))
plt.plot(x, x**2)
plt.plot(x, -1*(x**2))
plt.title("Plotting Something")
# Out:
# Text(0.5, 1.0, 'Plotting Something')

# %%
df.plot(figsize=(14,7), title='Bitcoin Price 2017-2018').set_ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## **A more challenging parsing**
# To demonstrate plotting two columns together, we'll try to add Ether prices to our df DataFrame. The ETH prices data can be found in the data/eth-price.csv file. The problem is that it seems like that CSV file was created by someone who really hated programmers. Take a look at it and see how ugly it looks like. We'll still use pandas to parse it.

# %%
eth = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/eth-price.csv")
eth
# Out:
#      Date(UTC)  UnixTimeStamp   Value
# 0     4/2/2017     1491091200   48.55
# 1     4/3/2017     1491177600   44.13
# 2     4/4/2017     1491264000   44.43
# 3     4/5/2017     1491350400   44.90
# 4     4/6/2017     1491436800   43.23
# ..         ...            ...     ...
# 357  3/28/2018     1522195200  445.93
# 358  3/29/2018     1522281600  383.90
# 359  3/30/2018     1522368000  393.82
# 360  3/31/2018     1522454400  394.07
# 361   4/1/2018     1522540800  378.85
#
# [362 rows x 3 columns]

# %%
eth.head()
# Out:
#   Date(UTC)  UnixTimeStamp  Value
# 0  4/2/2017     1491091200  48.55
# 1  4/3/2017     1491177600  44.13
# 2  4/4/2017     1491264000  44.43
# 3  4/5/2017     1491350400  44.90
# 4  4/6/2017     1491436800  43.23

# %%
eth = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/eth-price.csv", parse_dates=True)
print(eth.dtypes)
eth.head()
# Out:
# Date(UTC)         object
# UnixTimeStamp      int64
# Value            float64
# dtype: object
#   Date(UTC)  UnixTimeStamp  Value
# 0  4/2/2017     1491091200  48.55
# 1  4/3/2017     1491177600  44.13
# 2  4/4/2017     1491264000  44.43
# 3  4/5/2017     1491350400  44.90
# 4  4/6/2017     1491436800  43.23

# %%
pd.to_datetime(eth["UnixTimeStamp"]).head()
# Out:
# 0   1970-01-01 00:00:01.491091200
# 1   1970-01-01 00:00:01.491177600
# 2   1970-01-01 00:00:01.491264000
# 3   1970-01-01 00:00:01.491350400
# 4   1970-01-01 00:00:01.491436800
# Name: UnixTimeStamp, dtype: datetime64[ns]

# %%
df.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
pd.to_datetime(eth["Date(UTC)"]).head()
# Out:
# 0   2017-04-02
# 1   2017-04-03
# 2   2017-04-04
# 3   2017-04-05
# 4   2017-04-06
# Name: Date(UTC), dtype: datetime64[ns]

# %%
eth = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/eth-price.csv", parse_dates=[0]).head()

# %%
eth = pd.read_csv("/content/freecodecamp-intro-to-pandas/data/eth-price.csv",
                  index_col=0,
                  parse_dates=True)
print(eth.info())
eth.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 362 entries, 2017-04-02 to 2018-04-01
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UnixTimeStamp  362 non-null    int64
#  1   Value          362 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 8.5 KB
# None
#             UnixTimeStamp  Value
# Date(UTC)
# 2017-04-02     1491091200  48.55
# 2017-04-03     1491177600  44.13
# 2017-04-04     1491264000  44.43
# 2017-04-05     1491350400  44.90
# 2017-04-06     1491436800  43.23

# %%
prices= pd.DataFrame(index=df.index)

# %%
prices
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
prices.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2017-04-02 00:00:00, 2017-04-03 00:00:00, 2017-04-04 00:00:00, 2017-04-05 00:00:00, 2017-04-06 00:00:00]

# %%
prices["Bitcoin"] = df["Price"]
prices["Ether"] = eth["Value"]
prices.head()
# Out:
#                 Bitcoin  Ether
# Timestamp
# 2017-04-02  1099.169125  48.55
# 2017-04-03  1141.813000  44.13
# 2017-04-04  1141.600363  44.43
# 2017-04-05  1133.079314  44.90
# 2017-04-06  1196.307937  43.23

# %%
prices.plot(figsize=(12,6))

# %%
prices.loc["2017-04-03":"2017-04-05	"].plot(figsize=(12,6))
