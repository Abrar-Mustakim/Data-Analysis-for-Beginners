# %%
import pandas as pd
import numpy as np

# %%
#!git https://github.com/ine-rmotr-curriculum/freecodecamp-intro-to-pandas.git

# %%
g7_pop = pd.Series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523])

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
g7_pop.name = "G7 Population in millions"

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.values
# Out:
# array([ 35.467,  63.951,  80.94 ,  60.665, 127.061,  64.511, 318.523])

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
type(g7_pop.values)
# Out:
# numpy.ndarray

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[0]
# Out:
# 35.467

# %%
g7_pop.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
g7_pop[6]
# Out:
# 318.523

# %%
l = ["a", "b", "c"]

# %%
#let's make it something like dictionary, we will just update the keys and will attach it

g7_pop.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',
]

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# <h3>Now, the table will look like this </h3>
# <img src="https://camo.githubusercontent.com/00a0c2156fd946263e5fe105ae087c85de419882/68747470733a2f2f757365722d696d616765732e67697468756275736572636f6e74656e742e636f6d2f3837323239362f33383134393635362d62356365393831362d333433312d313165382d383865342d3139353735366532353335352e706e67">

# %%
#let's make dictionary with pandas
pd.Series({
    'Canada': 35.467,
    'France': 63.951,
    'Germany': 80.94,
    'Italy': 60.665,
    'Japan': 127.061,
    'United Kingdom': 64.511,
    'United States': 318.523
}, name = "G7 Population in millions")
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
pd.Series(
    [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523],
    index=['Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',],
    name="G7 Population in millions",
)
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
pd.Series(g7_pop, index=["United States", "Japan", "Italy", "Germany"])
# Out:
# United States    318.523
# Japan            127.061
# Italy             60.665
# Germany           80.940
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# <h3><b>Indexing</b></h3>

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop["Canada"]
# Out:
# 35.467

# %% [markdown]
# Numeric positions can also be used, with the iloc attribute

# %%
g7_pop.iloc[0]  #0 index
# Out:
# 35.467

# %%
g7_pop.iloc[1]
# Out:
# 63.951

# %%
g7_pop[1:]
# Out:
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[2::2]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[-1]
# Out:
# 318.523

# %%
g7_pop.iloc[-1]
# Out:
# 318.523

# %%
#Selecting Multiple elements at once
g7_pop[["Canada", "Japan"]]
# Out:
# Canada     35.467
# Japan     127.061
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop["Canada":"Japan"]
# Out:
# Canada      35.467
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.iloc[[0, 1]]
# Out:
# Canada    35.467
# France    63.951
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# <h3><b>Conditional selection (boolean arrays)</b></h3>
# The same boolean array techniques we saw applied to numpy arrays can be used for Pandas Series:

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop > 40
# Out:
# Canada            False
# France             True
# Germany            True
# Italy              True
# Japan              True
# United Kingdom     True
# United States      True
# Name: G7 Population in millions, dtype: bool

# %%
g7_pop[g7_pop > 40]
# Out:
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# 107.30257142857144

# %%
g7_pop[g7_pop > g7_pop.mean()]
# Out:
# Japan            127.061
# United States    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.std()
# Out:
# 97.24996987121581

# %%
g7_pop.var()
# Out:
# 9457.556639952383

# %% [markdown]
# ~ not
#
# | or
#
# & and

# %%
g7_pop[(g7_pop > g7_pop.mean()-g7_pop.std() / 2) | (g7_pop > g7_pop.mean() + g7_pop.std() / 2)]
# Out:
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# <h3><b>Operations and methods</b></h3>
# Series also support vectorized operations and aggregation functions as Numpy:

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop * 1_000_000
# Out:
# Canada             35467000.0
# France             63951000.0
# Germany            80940000.0
# Italy              60665000.0
# Japan             127061000.0
# United Kingdom     64511000.0
# United States     318523000.0
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# 107.30257142857144

# %%
np.log(g7_pop)
# Out:
# Canada            3.568603
# France            4.158117
# Germany           4.393708
# Italy             4.105367
# Japan             4.844667
# United Kingdom    4.166836
# United States     5.763695
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop["France":"Italy"].mean()
# Out:
# 68.51866666666666

# %% [markdown]
# <h3><b>Boolean arrays</b></h3>
# (Work in the same way as numpy)

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop > 80
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: G7 Population in millions, dtype: bool

# %%
g7_pop[g7_pop > 80]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[(g7_pop > 80) | (g7_pop<40)]
# Out:
# Canada            35.467
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[(g7_pop > 80) & (g7_pop<200)]
# Out:
# Germany     80.940
# Japan      127.061
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# <h3><b>Modifying series</b></h3>

# %%
g7_pop["Canada"] = 40

# %%
g7_pop
# Out:
# Canada             40.000
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.iloc[-1] = 500

# %%
g7_pop
# Out:
# Canada             40.000
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     500.000
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[g7_pop < 70]
# Out:
# Canada            40.000
# France            63.951
# Italy             60.665
# United Kingdom    64.511
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[g7_pop < 70] = 99.99

# %%
g7_pop
# Out:
# Canada             99.990
# France             99.990
# Germany            80.940
# Italy              99.990
# Japan             127.061
# United Kingdom     99.990
# United States     500.000
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop
# Out:
# Canada             99.990
# France             99.990
# Germany            80.940
# Italy              99.990
# Japan             127.061
# United Kingdom     99.990
# United States     500.000
# Name: G7 Population in millions, dtype: float64
