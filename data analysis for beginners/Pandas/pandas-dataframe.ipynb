# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We'll keep our analysis of G7 countries and looking now at DataFrames. As said, a DataFrame looks a lot like a table
# <img src="https://camo.githubusercontent.com/097bd658f7b6e6ef396e013ecb737580474b8c00/68747470733a2f2f757365722d696d616765732e67697468756275736572636f6e74656e742e636f6d2f3837323239362f33383135333439322d37326330333263612d333434332d313165382d383066342d3964653930363061353132372e706e67">

# %%
df = pd.DataFrame({
    "Population" : [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    "GDP" : [1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075],
      "Surface": [9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067],
      "HDI":[
             0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
      ],
      "Continent": [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
      ]
})

# %%
df
# Out:
#    Population       GDP  Surface    HDI Continent
# 0      35.467   1785387  9984670  0.913   America
# 1      63.951   2833687   640679  0.888    Europe
# 2      80.940   3874437   357114  0.916    Europe
# 3      60.665   2167744   301336  0.873    Europe
# 4     127.061   4602367   377930  0.891      Asia
# 5      64.511   2950039   242495  0.907    Europe
# 6     318.523  17348075  9525067  0.915   America

# %%
df.index = [
            'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',
]

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  7 non-null      float64
#  1   GDP         7 non-null      int64
#  2   Surface     7 non-null      int64
#  3   HDI         7 non-null      float64
#  4   Continent   7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP       Surface       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.dtypes
# Out:
# Population    float64
# GDP             int64
# Surface         int64
# HDI           float64
# Continent      object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      2
# float64    2
# object     1
# dtype: int64

# %% [markdown]
# <h3>Indexing, Selection and Slicing</h3>

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.loc["United Kingdom"]
# Out:
# Population     64.511
# GDP           2950039
# Surface        242495
# HDI             0.907
# Continent      Europe
# Name: United Kingdom, dtype: object

# %%
df.iloc[5]
# Out:
# Population     64.511
# GDP           2950039
# Surface        242495
# HDI             0.907
# Continent      Europe
# Name: United Kingdom, dtype: object

# %%
df["Population"]
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df["Population"].to_frame()
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %%
df[["Population", "GDP"]]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
df[1:3]
# Out:
#          Population      GDP  Surface    HDI Continent
# France       63.951  2833687   640679  0.888    Europe
# Germany      80.940  3874437   357114  0.916    Europe

# %%
df.loc["Italy"]
# Out:
# Population     60.665
# GDP           2167744
# Surface        301336
# HDI             0.873
# Continent      Europe
# Name: Italy, dtype: object

# %%
df.loc["France":"Italy"]
# Out:
#          Population      GDP  Surface    HDI Continent
# France       63.951  2833687   640679  0.888    Europe
# Germany      80.940  3874437   357114  0.916    Europe
# Italy        60.665  2167744   301336  0.873    Europe

# %%
df.loc["France":"Italy", "GDP"]
# Out:
# France     2833687
# Germany    3874437
# Italy      2167744
# Name: GDP, dtype: int64

# %%
df.loc["France": "Italy", ["Population", "GDP"]]
# Out:
#          Population      GDP
# France       63.951  2833687
# Germany      80.940  3874437
# Italy        60.665  2167744

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# Population     35.467
# GDP           1785387
# Surface       9984670
# HDI             0.913
# Continent     America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population     318.523
# GDP           17348075
# Surface        9525067
# HDI              0.915
# Continent      America
# Name: United States, dtype: object

# %%
df.iloc[1:3]
# Out:
#          Population      GDP  Surface    HDI Continent
# France       63.951  2833687   640679  0.888    Europe
# Germany      80.940  3874437   357114  0.916    Europe

# %%
df.iloc[[1,4,2]]
# Out:
#          Population      GDP  Surface    HDI Continent
# France       63.951  2833687   640679  0.888    Europe
# Japan       127.061  4602367   377930  0.891      Asia
# Germany      80.940  3874437   357114  0.916    Europe

# %%
df.iloc[1:3, 2]
# Out:
# France     640679
# Germany    357114
# Name: Surface, dtype: int64

# %%
df.iloc[1:3, [1,3]]
# Out:
#              GDP    HDI
# France   2833687  0.888
# Germany  3874437  0.916

# %%
df.iloc[1:3, 1:3]
# Out:
#              GDP  Surface
# France   2833687   640679
# Germany  3874437   357114

# %% [markdown]
# **RECOMMENDED: Always use loc and iloc to reduce ambiguity, specially with DataFrames with numeric indexes.**

# %% [markdown]
# <b>Conditional selection (boolean arrays)</b>

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df["Population"] > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df[df["Population"] > 70]
# Out:
#                Population       GDP  Surface    HDI Continent
# Germany            80.940   3874437   357114  0.916    Europe
# Japan             127.061   4602367   377930  0.891      Asia
# United States     318.523  17348075  9525067  0.915   America

# %%
df.loc[df["Population"] > 70, "Population"]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: Population, dtype: float64

# %%
df.loc[df["Population"] > 70, ["Population", "GDP"]]
# Out:
#                Population       GDP
# Germany            80.940   3874437
# Japan             127.061   4602367
# United States     318.523  17348075

# %% [markdown]
# ### **Dropping stuff**

# %%
df.drop("Canada")
# Out:
#                 Population       GDP  Surface    HDI Continent
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.drop(["Canada", "France"])
# Out:
#                 Population       GDP  Surface    HDI Continent
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.drop(columns=["Population", "Surface"])
# Out:
#                      GDP    HDI Continent
# Canada           1785387  0.913   America
# France           2833687  0.888    Europe
# Germany          3874437  0.916    Europe
# Italy            2167744  0.873    Europe
# Japan            4602367  0.891      Asia
# United Kingdom   2950039  0.907    Europe
# United States   17348075  0.915   America

# %%
df.drop(["Canada", "Germany"], axis=0)
# Out:
#                 Population       GDP  Surface    HDI Continent
# France              63.951   2833687   640679  0.888    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.drop(["Population", "GDP"], axis=1)
# Out:
#                 Surface    HDI Continent
# Canada          9984670  0.913   America
# France           640679  0.888    Europe
# Germany          357114  0.916    Europe
# Italy            301336  0.873    Europe
# Japan            377930  0.891      Asia
# United Kingdom   242495  0.907    Europe
# United States   9525067  0.915   America

# %%
df.drop(["Population", "HDI"], axis="columns")
# Out:
#                      GDP  Surface Continent
# Canada           1785387  9984670   America
# France           2833687   640679    Europe
# Germany          3874437   357114    Europe
# Italy            2167744   301336    Europe
# Japan            4602367   377930      Asia
# United Kingdom   2950039   242495    Europe
# United States   17348075  9525067   America

# %%
df.drop(["Canada", "Italy"], axis="rows")
# Out:
#                 Population       GDP  Surface    HDI Continent
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %% [markdown]
# ## **Operations**

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df[["Population","GDP"]] / 100
# Out:
#                 Population        GDP
# Canada             0.35467   17853.87
# France             0.63951   28336.87
# Germany            0.80940   38744.37
# Italy              0.60665   21677.44
# Japan              1.27061   46023.67
# United Kingdom     0.64511   29500.39
# United States      3.18523  173480.75

# %%
crisis = pd.Series([-1_000_000, -0.3], index=['GDP', 'HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[["GDP", "HDI"]]
# Out:
#                      GDP    HDI
# Canada           1785387  0.913
# France           2833687  0.888
# Germany          3874437  0.916
# Italy            2167744  0.873
# Japan            4602367  0.891
# United Kingdom   2950039  0.907
# United States   17348075  0.915

# %%
df[["GDP", "HDI"]] + crisis
# Out:
#                        GDP    HDI
# Canada            785387.0  0.613
# France           1833687.0  0.588
# Germany          2874437.0  0.616
# Italy            1167744.0  0.573
# Japan            3602367.0  0.591
# United Kingdom   1950039.0  0.607
# United States   16348075.0  0.615

# %% [markdown]
# ## **Modifying DataFrames**

# %% [markdown]
# ## <b>Adding a new column

# %%
langs = pd.Series(['French', 'German', 'Italian'],
                  index=['France', 'Germany', 'Italy'],
                  name = "language")

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: language, dtype: object

# %%
df["language"] = langs

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent language
# Canada              35.467   1785387  9984670  0.913   America      NaN
# France              63.951   2833687   640679  0.888    Europe   French
# Germany             80.940   3874437   357114  0.916    Europe   German
# Italy               60.665   2167744   301336  0.873    Europe  Italian
# Japan              127.061   4602367   377930  0.891      Asia      NaN
# United Kingdom      64.511   2950039   242495  0.907    Europe      NaN
# United States      318.523  17348075  9525067  0.915   America      NaN

# %%
#Replace value per columns
df["language"] = "ENGLISH"

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent language
# Canada              35.467   1785387  9984670  0.913   America  ENGLISH
# France              63.951   2833687   640679  0.888    Europe  ENGLISH
# Germany             80.940   3874437   357114  0.916    Europe  ENGLISH
# Italy               60.665   2167744   301336  0.873    Europe  ENGLISH
# Japan              127.061   4602367   377930  0.891      Asia  ENGLISH
# United Kingdom      64.511   2950039   242495  0.907    Europe  ENGLISH
# United States      318.523  17348075  9525067  0.915   America  ENGLISH

# %%
df.rename(
    columns={
        "GDP" : "Gross Domestic Product",
        "HDI" : "Human Development Index"
    },
    index={
        "United Kingdom" : "UK",
        "United States" : "USA"

    }
    
)
# Out:
#          Population  Gross Domestic Product  ...  Continent  language
# Canada       35.467                 1785387  ...    America   ENGLISH
# France       63.951                 2833687  ...     Europe   ENGLISH
# Germany      80.940                 3874437  ...     Europe   ENGLISH
# Italy        60.665                 2167744  ...     Europe   ENGLISH
# Japan       127.061                 4602367  ...       Asia   ENGLISH
# UK           64.511                 2950039  ...     Europe   ENGLISH
# USA         318.523                17348075  ...    America   ENGLISH
#
# [7 rows x 6 columns]

# %%
df.rename(index=str.upper)
# Out:
#                 Population       GDP  Surface    HDI Continent language
# CANADA              35.467   1785387  9984670  0.913   America  ENGLISH
# FRANCE              63.951   2833687   640679  0.888    Europe  ENGLISH
# GERMANY             80.940   3874437   357114  0.916    Europe  ENGLISH
# ITALY               60.665   2167744   301336  0.873    Europe  ENGLISH
# JAPAN              127.061   4602367   377930  0.891      Asia  ENGLISH
# UNITED KINGDOM      64.511   2950039   242495  0.907    Europe  ENGLISH
# UNITED STATES      318.523  17348075  9525067  0.915   America  ENGLISH

# %%
df.rename(index=lambda x: x.lower())
# Out:
#                 Population       GDP  Surface    HDI Continent language
# canada              35.467   1785387  9984670  0.913   America  ENGLISH
# france              63.951   2833687   640679  0.888    Europe  ENGLISH
# germany             80.940   3874437   357114  0.916    Europe  ENGLISH
# italy               60.665   2167744   301336  0.873    Europe  ENGLISH
# japan              127.061   4602367   377930  0.891      Asia  ENGLISH
# united kingdom      64.511   2950039   242495  0.907    Europe  ENGLISH
# united states      318.523  17348075  9525067  0.915   America  ENGLISH

# %%
df.rename(index=str.upper)
# Out:
#                 Population       GDP  Surface    HDI Continent language
# CANADA              35.467   1785387  9984670  0.913   America  ENGLISH
# FRANCE              63.951   2833687   640679  0.888    Europe  ENGLISH
# GERMANY             80.940   3874437   357114  0.916    Europe  ENGLISH
# ITALY               60.665   2167744   301336  0.873    Europe  ENGLISH
# JAPAN              127.061   4602367   377930  0.891      Asia  ENGLISH
# UNITED KINGDOM      64.511   2950039   242495  0.907    Europe  ENGLISH
# UNITED STATES      318.523  17348075  9525067  0.915   America  ENGLISH

# %%
#Drop the column
df.drop(columns=["language"], inplace=True)

# %% [markdown]
# ### **Adding values**

# %%
df.append(pd.Series(
    {
        "Population": 3,
      "GDP": 1_000_000
    }, name="China"
))
# Out:
#                 Population         GDP    Surface    HDI Continent
# Canada              35.467   1785387.0  9984670.0  0.913   America
# France              63.951   2833687.0   640679.0  0.888    Europe
# Germany             80.940   3874437.0   357114.0  0.916    Europe
# Italy               60.665   2167744.0   301336.0  0.873    Europe
# Japan              127.061   4602367.0   377930.0  0.891      Asia
# United Kingdom      64.511   2950039.0   242495.0  0.907    Europe
# United States      318.523  17348075.0  9525067.0  0.915   America
# China                3.000   1000000.0        NaN    NaN       NaN

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
#You can directly set the new index and values to the DataFrame:
df.loc["China"] = pd.Series(
    {
        "Population": 3,
      "GDP": 1_000_000,
     "Continent":"Asia"
    }
)

# %%
df
# Out:
#                 Population       GDP    Surface    HDI Continent
# Canada              35.467   1785387  9984670.0  0.913   America
# France              63.951   2833687   640679.0  0.888    Europe
# Germany             80.940   3874437   357114.0  0.916    Europe
# Italy               60.665   2167744   301336.0  0.873    Europe
# Japan              127.061   4602367   377930.0  0.891      Asia
# United Kingdom      64.511   2950039   242495.0  0.907    Europe
# United States      318.523  17348075  9525067.0  0.915   America
# China                3.000   1000000        NaN    NaN      Asia

# %%
df.drop("China", inplace=True)

# %%
df
# Out:
#                 Population       GDP    Surface    HDI Continent
# Canada              35.467   1785387  9984670.0  0.913   America
# France              63.951   2833687   640679.0  0.888    Europe
# Germany             80.940   3874437   357114.0  0.916    Europe
# Italy               60.665   2167744   301336.0  0.873    Europe
# Japan              127.061   4602367   377930.0  0.891      Asia
# United Kingdom      64.511   2950039   242495.0  0.907    Europe
# United States      318.523  17348075  9525067.0  0.915   America

# %%
# More radical index changes
df.reset_index()
# Out:
#             index  Population       GDP    Surface    HDI Continent
# 0          Canada      35.467   1785387  9984670.0  0.913   America
# 1          France      63.951   2833687   640679.0  0.888    Europe
# 2         Germany      80.940   3874437   357114.0  0.916    Europe
# 3           Italy      60.665   2167744   301336.0  0.873    Europe
# 4           Japan     127.061   4602367   377930.0  0.891      Asia
# 5  United Kingdom      64.511   2950039   242495.0  0.907    Europe
# 6   United States     318.523  17348075  9525067.0  0.915   America

# %%
df
# Out:
#                 Population       GDP    Surface    HDI Continent
# Canada              35.467   1785387  9984670.0  0.913   America
# France              63.951   2833687   640679.0  0.888    Europe
# Germany             80.940   3874437   357114.0  0.916    Europe
# Italy               60.665   2167744   301336.0  0.873    Europe
# Japan              127.061   4602367   377930.0  0.891      Asia
# United Kingdom      64.511   2950039   242495.0  0.907    Europe
# United States      318.523  17348075  9525067.0  0.915   America

# %%
df.set_index("Population")
# Out:
#                  GDP    Surface    HDI Continent
# Population
# 35.467       1785387  9984670.0  0.913   America
# 63.951       2833687   640679.0  0.888    Europe
# 80.940       3874437   357114.0  0.916    Europe
# 60.665       2167744   301336.0  0.873    Europe
# 127.061      4602367   377930.0  0.891      Asia
# 64.511       2950039   242495.0  0.907    Europe
# 318.523     17348075  9525067.0  0.915   America

# %%
df[["Population", "GDP"]]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
#let's find out gdp per capita and add it to column
df["GDP per Capita"] = df["GDP"] / df["Population"]

# %%
df
# Out:
#                 Population       GDP  ...  Continent  GDP per Capita
# Canada              35.467   1785387  ...    America    50339.385908
# France              63.951   2833687  ...     Europe    44310.284437
# Germany             80.940   3874437  ...     Europe    47868.013343
# Italy               60.665   2167744  ...     Europe    35733.025633
# Japan              127.061   4602367  ...       Asia    36221.712406
# United Kingdom      64.511   2950039  ...     Europe    45729.239975
# United States      318.523  17348075  ...    America    54464.120330
#
# [7 rows x 6 columns]

# %%
df.head()
# Out:
#          Population      GDP    Surface    HDI Continent  GDP per Capita
# Canada       35.467  1785387  9984670.0  0.913   America    50339.385908
# France       63.951  2833687   640679.0  0.888    Europe    44310.284437
# Germany      80.940  3874437   357114.0  0.916    Europe    47868.013343
# Italy        60.665  2167744   301336.0  0.873    Europe    35733.025633
# Japan       127.061  4602367   377930.0  0.891      Asia    36221.712406

# %%
df.describe()
# Out:
#        Population           GDP       Surface       HDI  GDP per Capita
# count    7.000000  7.000000e+00  7.000000e+00  7.000000        7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429    44952.254576
# std     97.249970  5.494020e+06  4.576187e+06  0.016592     6954.983875
# min     35.467000  1.785387e+06  2.424950e+05  0.873000    35733.025633
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500    40265.998421
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000    45729.239975
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000    49103.699626
# max    318.523000  1.734808e+07  9.984670e+06  0.916000    54464.120330

# %%
population = df["Population"]

# %%
population.min(), population.max()
# Out:
# (35.467, 318.523)

# %%
population.sum()
# Out:
# 751.118

# %%
population.sum() / len(population)
# Out:
# 107.30257142857144

# %%
population.mean()
# Out:
# 107.30257142857144

# %%
population.std()
# Out:
# 97.24996987121581

# %%
population.var()
# Out:
# 9457.556639952383

# %%
population.median()
# Out:
# 64.511

# %%
population.describe()
# Out:
# count      7.000000
# mean     107.302571
# std       97.249970
# min       35.467000
# 25%       62.308000
# 50%       64.511000
# 75%      104.000500
# max      318.523000
# Name: Population, dtype: float64

# %%
population.quantile(.25)
# Out:
# 62.308

# %%
population.quantile([.2, .4, .6, .8, 1])
# Out:
# 0.2     61.3222
# 0.4     64.1750
# 0.6     74.3684
# 0.8    117.8368
# 1.0    318.5230
# Name: Population, dtype: float64
